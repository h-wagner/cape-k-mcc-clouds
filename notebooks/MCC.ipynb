# %%
import act
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt

# %%
# Set your username and token here!
username = 'etomasiuk'
token = '2b2f7b43b2346a9d'

# Set the datastream and start/enddates
datastream = 'kcgsondewnpnM1.b1'
startdate = '2024-09-16'
enddate = '2024-09-19'
# Use ACT to easily download the data.  Watch for the data citation!  Show some support
# for ARM's instrument experts and cite their data if you use it in a publication
result = act.discovery.download_arm_data(username, token, datastream, startdate, enddate)
# Out:
# [DOWNLOADING] kcgsondewnpnM1.b1.20240916.173000.cdf
# [DOWNLOADING] kcgsondewnpnM1.b1.20240916.113000.cdf
# [DOWNLOADING] kcgsondewnpnM1.b1.20240918.000800.cdf
# [DOWNLOADING] kcgsondewnpnM1.b1.20240917.053000.cdf
# [DOWNLOADING] kcgsondewnpnM1.b1.20240918.113000.cdf
# [DOWNLOADING] kcgsondewnpnM1.b1.20240916.233000.cdf
# [DOWNLOADING] kcgsondewnpnM1.b1.20240918.233000.cdf
# [DOWNLOADING] kcgsondewnpnM1.b1.20240917.233000.cdf
# [DOWNLOADING] kcgsondewnpnM1.b1.20240917.113000.cdf
# [DOWNLOADING] kcgsondewnpnM1.b1.20240918.173000.cdf
# [DOWNLOADING] kcgsondewnpnM1.b1.20240918.053000.cdf
# [DOWNLOADING] kcgsondewnpnM1.b1.20240916.053000.cdf
# [DOWNLOADING] kcgsondewnpnM1.b1.20240917.173000.cdf
#
# If you use these data to prepare a publication, please cite:
#
# Keeler, E., Burk, K., & Kyrouac, J. Balloon-Borne Sounding System (SONDEWNPN),
# 2024-09-16 to 2024-09-19, ARM Mobile Facility (KCG), kennaook ⁄ Cape Grim,
# Tasmania, Australia; AMF2 (main site for CAPE-k) (M1). Atmospheric Radiation
# Measurement (ARM) User Facility. https://doi.org/10.5439/1595321

# %%
# Let's read in the data using ACT and check out the data
ds_mpl = act.io.read_arm_netcdf(result)

ds_mpl
# Out:
# <xarray.Dataset> Size: 2MB
# Dimensions:      (time: 21579)
# Coordinates:
#   * time         (time) datetime64[ns] 173kB 2024-09-16T05:30:00 ... 2024-09-...
# Data variables: (12/24)
#     base_time    (time) datetime64[ns] 173kB 2024-09-16 ... 2024-09-18
#     time_offset  (time) datetime64[ns] 173kB 2024-09-16T05:30:00 ... 2024-09-...
#     pres         (time) float32 86kB dask.array<chunksize=(1719,), meta=np.ndarray>
#     qc_pres      (time) int32 86kB dask.array<chunksize=(1719,), meta=np.ndarray>
#     tdry         (time) float32 86kB dask.array<chunksize=(1719,), meta=np.ndarray>
#     qc_tdry      (time) int32 86kB dask.array<chunksize=(1719,), meta=np.ndarray>
#     ...           ...
#     wstat        (time) float32 86kB dask.array<chunksize=(1719,), meta=np.ndarray>
#     asc          (time) float32 86kB dask.array<chunksize=(1719,), meta=np.ndarray>
#     qc_asc       (time) int32 86kB dask.array<chunksize=(1719,), meta=np.ndarray>
#     lat          (time) float32 86kB dask.array<chunksize=(1719,), meta=np.ndarray>
#     lon          (time) float32 86kB dask.array<chunksize=(1719,), meta=np.ndarray>
#     alt          (time) float32 86kB dask.array<chunksize=(1719,), meta=np.ndarray>
# Attributes: (12/36)
#     command_line:               sonde_ingest -s kcg -f M1
#     Conventions:                ARM-1.2
#     process_version:            ingest-sonde-10.15-1.el7
#     dod_version:                sondewnpn-b1-2.3
#     input_source:               /data/collection/kcg/kcgsondeM1.00/kcgsonde-c...
#     site_id:                    kcg
#     ...                         ...
#     doi:                        10.5439/1595321
#     history:                    created by user dsmgr on machine prod-proc3.a...
#     _file_dates:                ['20240916', '20240916', '20240916', '2024091...
#     _file_times:                ['053000', '113000', '173000', '233000', '053...
#     _datastream:                kcgsondewnpnM1.b1
#     _arm_standards_flag:        1

# %%
# Skew-T plot

# %%
# Let's set a longer time period
startdate = '2024-09-16T23:00:00'
enddate = '2024-09-17T23:00:00'

# SONDE
datastream = 'kcgsondewnpnM1.b1'
result = act.discovery.download_arm_data(username, token, datastream, startdate, enddate)
result.sort()
ds_sonde = act.io.read_arm_netcdf(result[1])

# Plot enhanced Skew-T plot
display = act.plotting.SkewTDisplay(ds_sonde)
display.plot_enhanced_skewt(color_field='alt')

plt.show()
# Out:
# [DOWNLOADING] kcgsondewnpnM1.b1.20240917.053000.cdf
# [DOWNLOADING] kcgsondewnpnM1.b1.20240916.233000.cdf
# [DOWNLOADING] kcgsondewnpnM1.b1.20240917.113000.cdf
# [DOWNLOADING] kcgsondewnpnM1.b1.20240917.173000.cdf
#
# If you use these data to prepare a publication, please cite:
#
# Keeler, E., Burk, K., & Kyrouac, J. Balloon-Borne Sounding System (SONDEWNPN),
# 2024-09-16 to 2024-09-17, ARM Mobile Facility (KCG), kennaook ⁄ Cape Grim,
# Tasmania, Australia; AMF2 (main site for CAPE-k) (M1). Atmospheric Radiation
# Measurement (ARM) User Facility. https://doi.org/10.5439/1595321

# %%
act.io.read_arm_netcdf(result[1])
# Out:
# <xarray.Dataset> Size: 160kB
# Dimensions:      (time: 1535)
# Coordinates:
#   * time         (time) datetime64[ns] 12kB 2024-09-17T05:30:00 ... 2024-09-1...
# Data variables: (12/24)
#     base_time    datetime64[ns] 8B 2024-09-17
#     time_offset  (time) datetime64[ns] 12kB 2024-09-17T05:30:00 ... 2024-09-1...
#     pres         (time) float32 6kB dask.array<chunksize=(1535,), meta=np.ndarray>
#     qc_pres      (time) int32 6kB dask.array<chunksize=(1535,), meta=np.ndarray>
#     tdry         (time) float32 6kB dask.array<chunksize=(1535,), meta=np.ndarray>
#     qc_tdry      (time) int32 6kB dask.array<chunksize=(1535,), meta=np.ndarray>
#     ...           ...
#     wstat        (time) float32 6kB dask.array<chunksize=(1535,), meta=np.ndarray>
#     asc          (time) float32 6kB dask.array<chunksize=(1535,), meta=np.ndarray>
#     qc_asc       (time) int32 6kB dask.array<chunksize=(1535,), meta=np.ndarray>
#     lat          (time) float32 6kB dask.array<chunksize=(1535,), meta=np.ndarray>
#     lon          (time) float32 6kB dask.array<chunksize=(1535,), meta=np.ndarray>
#     alt          (time) float32 6kB dask.array<chunksize=(1535,), meta=np.ndarray>
# Attributes: (12/36)
#     command_line:               sonde_ingest -s kcg -f M1
#     Conventions:                ARM-1.2
#     process_version:            ingest-sonde-10.15-1.el7
#     dod_version:                sondewnpn-b1-2.3
#     input_source:               /data/collection/kcg/kcgsondeM1.00/kcgsonde-c...
#     site_id:                    kcg
#     ...                         ...
#     doi:                        10.5439/1595321
#     history:                    created by user dsmgr on machine prod-proc3.a...
#     _file_dates:                ['20240917']
#     _file_times:                ['053000']
#     _datastream:                kcgsondewnpnM1.b1
#     _arm_standards_flag:        1

# %%
# We're going to use some test data that already exists within ACT
# Let's set a longer time period
startdate = '2024-09-16T00:00:00'
enddate = '2024-09-17T06:00:00'

# SONDE
datastream = 'kcgdlppiM1.b1'
result = act.discovery.download_arm_data(username, token, datastream, startdate, enddate)
result.sort()
# Out:
# [DOWNLOADING] kcgdlppiM1.b1.20240916.134844.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.092826.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.012754.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.205922.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.063816.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.084824.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.160901.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.081823.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240917.015941.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.045812.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.135845.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.143850.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.062815.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.022801.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240917.004934.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.005752.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.164904.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240917.002933.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.215924.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.103829.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.224928.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.230928.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.075821.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.001750.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240917.022942.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.195918.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.213923.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.004751.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240917.021941.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.234931.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.110832.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.144851.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.111833.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.031802.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.043810.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.020758.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.204920.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.082823.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240917.000933.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.233931.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.151856.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.231929.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240917.023942.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240917.044949.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.034805.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.232930.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.211923.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240917.041948.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.214924.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.154858.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.122836.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.093826.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.142849.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240917.005935.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.130840.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.013755.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240917.052951.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.074820.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.044811.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.180912.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240917.013939.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.113834.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.225928.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.184915.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.150854.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240917.050950.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.071819.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.003751.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.190915.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240917.035945.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.223928.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.115835.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.181913.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.163903.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.025801.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.174909.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240917.032944.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.104830.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240917.014939.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240917.034944.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.121836.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.051812.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.173909.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.072820.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240917.003934.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240917.053952.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.172908.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.221926.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.152857.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.203920.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.061814.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.073820.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.080821.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.132842.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240917.040946.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.140846.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240917.055953.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240917.045950.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.100828.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.021759.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.002750.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.033805.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.123837.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.010753.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.145853.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240917.011938.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.094827.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240917.031943.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240917.001933.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.052813.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.024801.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.165905.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.235932.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.133843.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.201919.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.054814.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.155859.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.162903.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240917.054953.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.040807.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240917.042948.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.023801.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.125839.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.064818.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.015758.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.124838.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.050812.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.185915.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240917.024942.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.114834.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.014756.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.083824.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.070818.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.212923.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.000749.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.153857.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.101828.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.170906.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.035806.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240917.025943.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.182914.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.183914.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240917.033944.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240917.051951.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.141848.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.175910.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.200919.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.194917.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.193917.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240917.030943.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240917.010936.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.041808.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.060814.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.220924.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.131841.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240917.020941.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.090825.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.161902.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240917.012938.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.030802.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.055814.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.011753.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.192917.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.091825.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.032803.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.171907.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.210922.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.120836.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.102829.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.112833.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.202919.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.065818.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.053814.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.095827.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.191916.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.085825.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240917.043948.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.042810.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.222927.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240916.105831.cdf
#
# If you use these data to prepare a publication, please cite:
#
# Newsom, R., Shi, Y., & Krishnamurthy, R. Doppler Lidar (DLPPI), 2024-09-16 to
# 2024-09-17, ARM Mobile Facility (KCG), kennaook ⁄ Cape Grim, Tasmania,
# Australia; AMF2 (main site for CAPE-k) (M1). Atmospheric Radiation Measurement
# (ARM) User Facility. https://doi.org/10.5439/1025186

# %%
ds = act.io.read_arm_netcdf(result)
ds
# Returns the wind retrieval information in a new object by default
# Note that the default snr_threshold of 0.008 was too high for the first profile
# Reducing it to 0.002 makes it show up but the quality of the data is likely suspect.
ds_wind = act.retrievals.compute_winds_from_ppi(ds, snr_threshold=0.01)

# Plot it up
display = act.plotting.TimeSeriesDisplay(ds_wind)
display.plot_barbs_from_spd_dir('wind_speed', 'wind_direction', invert_y_axis=False)

#Update the x-limits to make sure both wind profiles are shown
display.axes[0].set_xlim([np.datetime64(startdate), np.datetime64(enddate)])

plt.ylim(0, 2000)

plt.show()

# %%
# abovee is the wind data for 16th - 17th SEP

# %%
# We're going to use some test data that already exists within ACT
# Let's set a longer time period
startdate2 = '2024-09-19T05:00:00'
enddate2 = '2024-09-19T10:00:00'

# SONDE
datastream = 'kcgdlppiM1.b1'
result = act.discovery.download_arm_data(username, token, datastream, startdate2, enddate2)
result.sort()
# Out:
# [DOWNLOADING] kcgdlppiM1.b1.20240919.092403.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240919.081402.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240919.084402.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240919.070357.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240919.055352.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240919.051349.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240919.065356.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240919.085403.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240919.060353.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240919.083402.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240919.062355.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240919.073359.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240919.054352.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240919.094404.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240919.052350.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240919.080400.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240919.064356.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240919.090403.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240919.074400.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240919.091403.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240919.063355.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240919.072359.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240919.093404.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240919.095404.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240919.075400.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240919.082402.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240919.053351.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240919.050347.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240919.071359.cdf
# [DOWNLOADING] kcgdlppiM1.b1.20240919.061355.cdf
#
# If you use these data to prepare a publication, please cite:
#
# Newsom, R., Shi, Y., & Krishnamurthy, R. Doppler Lidar (DLPPI), 2024-09-19 to
# 2024-09-19, ARM Mobile Facility (KCG), kennaook ⁄ Cape Grim, Tasmania,
# Australia; AMF2 (main site for CAPE-k) (M1). Atmospheric Radiation Measurement
# (ARM) User Facility. https://doi.org/10.5439/1025186

# %%
ds = act.io.read_arm_netcdf(result)
ds
# Returns the wind retrieval information in a new object by default
# Note that the default snr_threshold of 0.008 was too high for the first profile
# Reducing it to 0.002 makes it show up but the quality of the data is likely suspect.
ds_wind = act.retrievals.compute_winds_from_ppi(ds, snr_threshold=0.01)

# Plot it up
display = act.plotting.TimeSeriesDisplay(ds_wind)
display.plot_barbs_from_spd_dir('wind_speed', 'wind_direction', invert_y_axis=False)

#Update the x-limits to make sure both wind profiles are shown
display.axes[0].set_xlim([np.datetime64(startdate2), np.datetime64(enddate2)])

plt.ylim(0, 2000)

plt.show()

# %%
# AOSMET - Just to get the wind data!
datastream3 = 'kcgaosmetS2.a1'
result = act.discovery.download_arm_data(username, token, datastream3, startdate2, enddate2)
ds_met = act.io.read_arm_netcdf(result)

# MPL to get the full record
datastream = 'kcg30smplcmask1zwangM1.c1'
result = act.discovery.download_arm_data(username, token, datastream, startdate2, enddate2)
ds_mpl = act.io.read_arm_netcdf(result)
# Out:
# [DOWNLOADING] kcgaosmetS2.a1.20240917.000000.nc
#
# If you use these data to prepare a publication, please cite:
#
# Kyrouac, J., & Tuftedal, M. Meteorological Measurements associated with the
# Aerosol Observing System (AOSMET), 2024-09-16 to 2024-09-17, ARM Mobile Facility
# (KCG), kennaook ⁄ Cape Grim, Tasmania, Australia; Supplementary Facility 2 (S2).
# Atmospheric Radiation Measurement (ARM) User Facility.
# https://doi.org/10.5439/1984920
#
# [DOWNLOADING] kcg30smplcmask1zwangM1.c1.20240917.000003.nc
#
# If you use these data to prepare a publication, please cite:
#
# Sivaraman, C., Flynn, D., Riihimaki, L., Comstock, J., & Zhang, D. Cloud mask
# from Micropulse Lidar (30SMPLCMASK1ZWANG), 2024-09-16 to 2024-09-17, ARM Mobile
# Facility (KCG), kennaook ⁄ Cape Grim, Tasmania, Australia; AMF2 (main site for
# CAPE-k) (M1). Atmospheric Radiation Measurement (ARM) User Facility.
# https://doi.org/10.5439/1508389

# %%
ds_met
# Out:
# <xarray.Dataset> Size: 2MB
# Dimensions:              (time: 33871)
# Coordinates:
#   * time                 (time) datetime64[ns] 271kB 2024-09-17T00:00:00.5000...
# Data variables: (12/17)
#     base_time            datetime64[ns] 8B 2024-09-17
#     time_offset          (time) datetime64[ns] 271kB 2024-09-17T00:00:00.5000...
#     rh_ambient           (time) float32 135kB dask.array<chunksize=(33871,), meta=np.ndarray>
#     temperature_ambient  (time) float32 135kB dask.array<chunksize=(33871,), meta=np.ndarray>
#     pressure_ambient     (time) float32 135kB dask.array<chunksize=(33871,), meta=np.ndarray>
#     wind_speed           (time) float32 135kB dask.array<chunksize=(33871,), meta=np.ndarray>
#     ...                   ...
#     heater_volts         (time) float32 135kB dask.array<chunksize=(33871,), meta=np.ndarray>
#     supply_volts         (time) float32 135kB dask.array<chunksize=(33871,), meta=np.ndarray>
#     ref_volts            (time) float32 135kB dask.array<chunksize=(33871,), meta=np.ndarray>
#     lat                  float32 4B ...
#     lon                  float32 4B ...
#     alt                  float32 4B ...
# Attributes: (12/21)
#     command_line:                aosmet_ingest -s kcg -f S2
#     Conventions:                 ARM-1.3
#     process_version:             ingest-aosmet-1.2-0.el7
#     dod_version:                 aosmet-a1-3.0
#     input_source:                /data/collection/kcg/kcgaosmetS2.00/kcgaosS3...
#     site_id:                     kcg
#     ...                          ...
#     doi:                         10.5439/1325987
#     history:                     created by user dsmgr on machine prod-proc4....
#     _file_dates:                 ['20240917']
#     _file_times:                 ['000000']
#     _datastream:                 kcgaosmetS2.a1
#     _arm_standards_flag:         1
